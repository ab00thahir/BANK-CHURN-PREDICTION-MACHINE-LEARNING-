# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/drive/MyDrive/project datasets/Bank Customer Churn Prediction.csv")
data
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
data.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
data.tail()
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 9995                2            1              0          96270.64      0
# 9996                1            1              1         101699.77      0
# 9997                1            0              1          42085.58      1
# 9998                2            1              0          92888.52      1
# 9999                1            1              0          38190.78      0

# %%
data.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
data.isna().any()
# Out:
# customer_id         False
# credit_score        False
# country             False
# gender              False
# age                 False
# tenure              False
# balance             False
# products_number     False
# credit_card         False
# active_member       False
# estimated_salary    False
# churn               False
# dtype: bool

# %%
data.shape
# Out:
# (10000, 12)

# %%
data.describe()
# Out:
#         customer_id  credit_score           age        tenure        balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        products_number  credit_card  active_member  estimated_salary  \
# count     10000.000000  10000.00000   10000.000000      10000.000000
# mean          1.530200      0.70550       0.515100     100090.239881
# ...

# %%
data.isnull().sum()*100/len(data)
# Out:
# customer_id         0.0
# credit_score        0.0
# country             0.0
# gender              0.0
# age                 0.0
# tenure              0.0
# balance             0.0
# products_number     0.0
# credit_card         0.0
# active_member       0.0
# estimated_salary    0.0
# churn               0.0
# dtype: float64

# %%
data.nunique()
# Out:
# customer_id         10000
# credit_score          460
# country                 3
# gender                  2
# age                    70
# tenure                 11
# balance              6382
# products_number         4
# credit_card             2
# active_member           2
# estimated_salary     9999
# churn                   2
# dtype: int64

# %%
from  sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data.country=le.fit_transform(data.country)
data.head()
# Out:
#    customer_id  credit_score  country  gender  age  tenure    balance  \
# 0     15634602           619        0  Female   42       2       0.00
# 1     15647311           608        2  Female   41       1   83807.86
# 2     15619304           502        0  Female   42       8  159660.80
# 3     15701354           699        0  Female   39       1       0.00
# 4     15737888           850        2  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
for i in data.columns:
  data[i]=le.fit_transform(data[i])

# %%
data.dtypes
# Out:
# customer_id         int64
# credit_score        int64
# country             int64
# gender              int64
# age                 int64
# tenure              int64
# balance             int64
# products_number     int64
# credit_card         int64
# active_member       int64
# estimated_salary    int64
# churn               int64
# dtype: object

# %%
data['churn'].value_counts()
# Out:
# churn
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
cor=data.corr()
cor['churn'].sort_values(ascending=False)
# Out:
# churn               1.000000
# age                 0.285537
# balance             0.097264
# country             0.035943
# estimated_salary    0.012081
# customer_id        -0.006264
# credit_card        -0.007138
# tenure             -0.014001
# credit_score       -0.026002
# products_number    -0.047820
# gender             -0.106512
# active_member      -0.156128
# Name: churn, dtype: float64

# %%
columns_to_drop = ["credit_score","credit_card","products_number","customer_id"]
data.drop (columns_to_drop, axis=1, inplace=True)
data.head()
# Out:
#    country  gender  age  tenure  balance  active_member  estimated_salary  \
# 0        0       0   24       2        0              1              5068
# 1        2       0   23       1      743              1              5639
# 2        0       0   24       8     5793              0              5707
# 3        0       0   21       1        0              0              4704
# 4        2       0   25       2     3696              1              3925
#
#    churn
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
y_train.value_counts()
# Out:
# churn
# 0    6378
# 1    1622
# Name: count, dtype: int64

# %% [markdown]
# **smoting**

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()

# %%
xres,yres=sm.fit_resample(x_train,y_train)

# %%
yres.value_counts()
# Out:
# churn
# 0    6378
# 1    6378
# Name: count, dtype: int64

# %%
x.head()
# Out:
#    country  gender  age  tenure  balance  active_member  estimated_salary
# 0        0       0   24       2        0              1              5068
# 1        2       0   23       1      743              1              5639
# 2        0       0   24       8     5793              0              5707
# 3        0       0   21       1        0              0              4704
# 4        2       0   25       2     3696              1              3925

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: churn, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sd=StandardScaler()

# %%
xtrain1=sd.fit_transform(x_train)
xtest1=sd.fit_transform(x_test)

# %% [markdown]
# # **Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=20,criterion='gini',max_depth=5,max_features=5)

# %%
rfc.fit(xtrain1,y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features=5, n_estimators=20)

# %%
ypred=rfc.predict(xtest1)

# %%
ypred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print('accuracy_scrore',accuracy_score(y_test,ypred))
# Out:
# accuracy_scrore 0.8315

# %%
print('confusion_matrics',confusion_matrix(y_test,ypred))
# Out:
# confusion_matrics [[1542   43]
#  [ 294  121]]

# %%
rfc.score(xtrain1,y_train)
# Out:
# 0.838

# %%
rfc.score(xtest1,y_test)
# Out:
# 0.8315

# %%
rfc.predict_proba(xtest1)
# Out:
# array([[0.78605141, 0.21394859],
#        [0.89099511, 0.10900489],
#        [0.82977131, 0.17022869],
#        ...,
#        [0.94326487, 0.05673513],
#        [0.89827165, 0.10172835],
#        [0.61263454, 0.38736546]])

# %% [markdown]
# # **Decision Tree Classifier**

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(xtrain1,y_train)
# Out:
# DecisionTreeClassifier()

# %%
ypred2=dt.predict(xtest1)

# %%
print('accuracy_score',accuracy_score(y_test,ypred2))
print('precision_score',precision_score(y_test,ypred2))
print('recall score is',recall_score(y_test,ypred2))
# Out:
# accuracy_score 0.7535
# precision_score 0.4117647058823529
# recall score is 0.43855421686746987

# %% [markdown]
# # **Gradient Boosting Classifier**

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc=GradientBoostingClassifier()

# %%
bggc=gbc.fit(xtrain1,y_train)

# %%
ypred3=bggc.predict(xtest1)

# %%
print('accuracy_score',accuracy_score(y_test,ypred3))
print('precision_score',precision_score(y_test,ypred3))
print('recall score is',recall_score(y_test,ypred3))
# Out:
# accuracy_score 0.8315
# precision_score 0.7166666666666667
# recall score is 0.3108433734939759

# %% [markdown]
# # **KNeighbors classifier**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(xtrain1,y_train)
# Out:
# KNeighborsClassifier()

# %%
ypred4=knn.predict(xtest1)

# %%
print('accuracy_score',accuracy_score(y_test,ypred4))
print('precision_score',precision_score(y_test,ypred4))
print('recall score is',recall_score(y_test,ypred4))
# Out:
# accuracy_score 0.8215
# precision_score 0.6330275229357798
# recall score is 0.3325301204819277

# %% [markdown]
# # **SVC**

# %%
from sklearn.svm import SVC

# %%
svm=SVC()

# %%
svm.fit(xtrain1,y_train)
# Out:
# SVC()

# %%
ypred5=svm.predict(xtest1)

# %%
print('accuracy_score',accuracy_score(y_test,ypred5))
print('precision_score',precision_score(y_test,ypred5))
print('recall score is',recall_score(y_test,ypred5))
# Out:
# accuracy_score 0.828
# precision_score 0.7709923664122137
# recall score is 0.2433734939759036

# %% [markdown]
# # **Logistic Regression**

# %%
from sklearn.preprocessing import StandardScaler

# %%
sd=StandardScaler()

# %%
xtrain=sd.fit_transform(xtrain1)

# %%
xtest=sd.fit_transform(xtest1)

# %%
xres=sd.fit_transform(xres)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(xtrain,y_train)
# Out:
# LogisticRegression()

# %%
ypred6=model.predict(xtest1)

# %%
ypred6
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.linear_model import LogisticRegression

# %%
model1=LogisticRegression()

# %%
model1.fit(xtrain1,y_train)
# Out:
# LogisticRegression()

# %%
ypred7=model1.predict(xtest1)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,mean_squared_error,classification_report

# %%
print('accuracy score',accuracy_score(y_test,ypred7))
# Out:
# accuracy score 0.8055

# %%
print('training score',model.score(xtrain1,y_train))
# Out:
# training score 0.806875

# %%
print('testing score',model.score(xtest1,y_test))
# Out:
# testing score 0.8055

# %%
print('confusion matrix/n',confusion_matrix(y_test,ypred7))
# Out:
# confusion matrix/n [[1535   50]
#  [ 339   76]]

# %%
print('precision score',precision_score(y_test,ypred7,average="macro"))
# Out:
# precision score 0.7111390625264691

# %%
print('mean squared error',mean_squared_error(y_test,ypred7))
# Out:
# mean squared error 0.1945

# %%
print(classification_report(y_test,ypred7))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      1585
#            1       0.60      0.18      0.28       415
#
#     accuracy                           0.81      2000
#    macro avg       0.71      0.58      0.58      2000
# weighted avg       0.77      0.81      0.76      2000

# %% [markdown]
# # **Hyperparameter tuning**

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn import metrics

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
param_grid={'n_estimators': [100, 200],'max_depth': [10,20],'min_samples_split': [2,5],'min_samples_leaf': [1,2]}

# %%
clf=GridSearchCV(model,param_grid=param_grid,cv=10,verbose=True,n_jobs=-1)

# %%
best_clf=clf.fit(xtrain1,y_train)
# Out:
# Fitting 10 folds for each of 16 candidates, totalling 160 fits

# %%
best_clf.best_estimator_
# Out:
# RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=200)

# %%
print (f'Accuracy - : {best_clf.score(xtest1,y_test):.3f}')
# Out:
# Accuracy - : 0.839

# %% [markdown]
# # **final data**

# %%
accuracy_results = {
    'Algorithm': ['Random Forest', 'Decision Tree', 'Gradient Boosting', 'KNeighbors', 'SVC', 'Logistic Regression'],
    'Accuracy Score': [
        accuracy_score(y_test, ypred),
        accuracy_score(y_test, ypred2),
        accuracy_score(y_test, ypred3),
        accuracy_score(y_test, ypred4),
        accuracy_score(y_test, ypred5),
        accuracy_score(y_test, ypred7)
    ]
}


results_df = pd.DataFrame(accuracy_results)
results_df
# Out:
#              Algorithm  Accuracy Score
# 0        Random Forest          0.8315
# 1        Decision Tree          0.7535
# 2    Gradient Boosting          0.8315
# 3           KNeighbors          0.8215
# 4                  SVC          0.8280
# 5  Logistic Regression          0.8055

# %%
import pandas as pd
import matplotlib.pyplot as plt
results_df = pd.DataFrame(accuracy_results)

plt.figure(figsize=(10, 6))
plt.barh(results_df['Algorithm'], results_df['Accuracy Score'], color='skyblue')
plt.xlabel('Accuracy Score')
plt.title('Model Accuracy Comparison')
plt.xlim(0, 1)
plt.grid(axis='x')

plt.show()

# %% [markdown]
# # **VISUALIZATION**

# %%
labels = 'Churned(Exited)','Retained'
sizes = [data.churn[data.churn == 1].count(), data.churn[data.churn == 0].count()]
explode = (0, 0.1)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
plt.title('Propotion of customers churned and retained',size=20)
plt.show()

# %%
fig,axarr = plt.subplots(2,2,figsize=(20,15))
sns.countplot(x='country',hue='churn',data=data,ax=axarr[0][0])
sns.countplot(x='gender',hue='churn',data=data,ax=axarr[0][1])
sns.countplot(x='active_member',hue='churn',data=data,ax=axarr[1][0])
sns.countplot(x='tenure',hue='churn',data=data,ax=axarr[1][1])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# # **Prediction system**

# %%
input_df = (2,0,23,1,743,1,5639)
np_df = np.asarray(input_df)
np_df_reshaped = np_df.reshape(1,-1)
prediction = best_clf.predict(np_df_reshaped)
print(prediction)
# Out:
# [0]

# %% [markdown]
# **saving the model**

# %%
import pickle

# %%
with open('model.pkl', 'wb') as f:
    pickle.dump(best_clf, f)
print("Model saved successfully!")

#load the model
with open('model.pkl', 'rb') as f:
    best_clf = pickle.load(f)
print("Model loaded successfully!")

#loaded model to make a prediction
loaded_prediction = best_clf.predict(np_df_reshaped)
print("Prediction using loaded model:", loaded_prediction)
# Out:
# Model saved successfully!
# Model loaded successfully!
# Prediction using loaded model: [0]

# %%
input_df = (2,0,23,1,743,1,5639)
np_df = np.asarray(input_df)
np_df_reshaped = np_df.reshape(1,-1)
prediction = best_clf.predict(np_df_reshaped)
print(prediction)
# Out:
# [0]
